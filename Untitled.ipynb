# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
df = pd.read_csv('../1/dataset/Laptop_price.csv')
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %%
print(f'Missing Values:{df.isna().sum()} \n')
print(f'Data Frame Shape:{df.shape} \n')
print(f'Duplicate: {df.duplicated().sum()} ')
# Out:
# Missing Values:Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64
#
# Data Frame Shape:(1000, 7)
#
# Duplicate: 0

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
encoder = LabelEncoder()
df['Brand'] = encoder.fit_transform(df['Brand'])
df.head()
# Out:
#    Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0      1         3.830296        16               512    11.185147  2.641094
# 1      0         2.912833         4              1000    11.311372  3.260012
# 2      4         3.241627         4               256    11.853023  2.029061
# 3      0         3.806248        16               512    12.280360  4.573865
# 4      0         3.268097        32              1000    14.990877  4.193472
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718

# %%
df = (df - df.min()) / (df.max() - df.min())
df
# Out:
#      Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0     0.25         0.932352  0.428571          0.344086     0.028967
# 1     0.00         0.563441  0.000000          1.000000     0.050097
# 2     1.00         0.695649  0.000000          0.000000     0.140771
# 3     0.00         0.922682  0.428571          0.344086     0.212308
# 4     0.00         0.706292  1.000000          1.000000     0.666055
# ..     ...              ...       ...               ...          ...
# 995   0.75         0.736646  0.000000          1.000000     0.263656
# 996   0.50         0.510253  0.142857          0.000000     0.279101
# 997   0.50         0.679140  0.000000          0.344086     0.276918
# 998   0.25         0.037235  0.142857          0.000000     0.034061
# 999   1.00         0.080580  0.000000          0.000000     0.928981
#
#        Weight     Price
# 0    0.214214  0.353939
# 1    0.421198  0.923946
# 2    0.009532  0.028917
# 3    0.860589  0.355609
# ...

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]
x
# Out:
#      Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight
# 0     0.25         0.932352  0.428571          0.344086     0.028967  0.214214
# 1     0.00         0.563441  0.000000          1.000000     0.050097  0.421198
# 2     1.00         0.695649  0.000000          0.000000     0.140771  0.009532
# 3     0.00         0.922682  0.428571          0.344086     0.212308  0.860589
# 4     0.00         0.706292  1.000000          1.000000     0.666055  0.733374
# ..     ...              ...       ...               ...          ...       ...
# 995   0.75         0.736646  0.000000          1.000000     0.263656  0.388553
# 996   0.50         0.510253  0.142857          0.000000     0.279101  0.585153
# 997   0.50         0.679140  0.000000          0.344086     0.276918  0.465543
# 998   0.25         0.037235  0.142857          0.000000     0.034061  0.621053
# 999   1.00         0.080580  0.000000          0.000000     0.928981  0.481686
#
# [1000 rows x 6 columns]

# %%
y
# Out:
# 0      0.353939
# 1      0.923946
# 2      0.028917
# 3      0.355609
# 4      0.976500
#          ...
# 995    0.923387
# 996    0.023242
# 997    0.320142
# 998    0.033587
# 999    0.009533
# Name: Price, Length: 1000, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 42, test_size=0.2)

# %%
gg = LinearRegression()
gg.fit(x_train, y_train)

gg
# Out:
# LinearRegression()

# %%
ypred = gg.predict(x_test)

# %%
mse = mean_squared_error(y_test, ypred)
print(f"Mean squared Error (MSE): {mse}")
# Out:
# Mean squared Error (MSE): 5.142280564356325e-05

# %%
r2 = r2_score(y_test, ypred)
print('R-squared:', r2)
# Out:
# R-squared: 0.9996478987127725

# %%
plt.scatter(y_test, ypred) # Menampilkan data prediksi
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--r') # Menampilkan garis
plt.title('Grafis Prediksi') # Judul
plt.xlabel('Nilai Sebenarnya') # Label bawah (x)
plt.ylabel('Prediksi') # Label samping/atas (y)
plt.show() # Perintah untuk menampilkan grafik
